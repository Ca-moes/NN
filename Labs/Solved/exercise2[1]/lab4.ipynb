# %% [markdown]
# # Exercise 4: LMS algorithm for stock price prediction
#
# ## 4.1 Introduction
#
# In this exercise the *trainlms* function given below will be used.
#
# **Tasks**
#
# 1. What does the function *trainlms* do?

# %%
import numpy as np

def predict(W, A):
    return W@np.vstack([-np.ones((1, A.shape[1])), A])

def trainlms(ni, x, d, W, max_epoch):
    w=W.copy()  # Copy of weights to not change original weights
    
    n=0  # Iterations number
    errors=[]
    while (n<max_epoch):
        n+=1  # Increase iteractions number
        y=predict(w, x)  # Make prediction based on current weights and input values
        e=d-y # Calculate error matrix -> desired - expected outputs
        w+=ni*e@np.vstack([-np.ones((1, x.shape[1])), x]).T  # Update errors: learning_rate * error
        error=np.sum(np.square(e)) 
        errors.append(error)
        if (error<0.02):
            break
    return w, errors

# %% [markdown]
# ## 4.2 Stock price movement
#
# In this experiment we will use the LMS algorithm in order to predict the stock price for a given stock. Load the data from file *stock.txt* into variable *data*. Numbers (elements of vector *data*) show the movement of average daily price of the given share in time. Plot the variable *data* using the following commands:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/My\ Drive/MIEIC/NN/exercise2[1]
data=np.loadtxt("stock.txt", delimiter=",")

print(data)

import matplotlib.pyplot as plt
plt.plot(range(1, data.shape[0]+1), data)
plt.show()
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/MIEIC/NN/exercise2[1]
# [183.35 210.26 214.58 214.36 229.04 199.32 203.02 213.71 201.54 245.35
#  219.03 238.02 222.02 205.7  174.35 190.18 203.97 215.83 231.49 214.84
#  202.23 173.53 181.16 148.12 178.15 179.09 190.47 190.73 155.93 156.66
#  138.9  166.83 151.45 165.21 206.64 170.25 158.17 146.52 140.63 163.85
#  189.44 212.95 219.97 213.68 192.39 189.87 195.83 185.06 192.2  226.31
#  210.14 203.82 198.05 188.79 181.04 165.08 176.82 194.66 215.64 193.73
#  193.16 180.14 149.81 138.93 171.2  190.08 176.88 176.37 150.28 164.23
#  139.97 148.53 150.8  161.31 167.55 194.3  180.83 146.55 171.8  172.52
#  188.95 219.83 190.75 203.71 195.17 187.47 163.97 194.88 186.25 221.66
#  234.34 219.65 210.34 179.24 189.42 183.05 184.15 206.99 205.8  196.47
#  194.92 174.1  161.27 156.88 194.45 206.79 188.01 194.26 185.98 178.62
#  171.61 156.83 163.33 204.55 185.24 183.74 180.39 189.12 176.08 185.65
#  217.03 220.8  207.63 237.17 218.2  201.81 190.05 197.65 222.42 227.66
#  227.12 226.35 215.54 198.27 207.58 220.6  232.32 243.92 243.58 241.19
#  221.24 181.33 204.45 171.85 206.02 200.78 206.16 202.9  182.28 180.14
#  192.17 176.4  199.22 215.79 227.95 211.93 218.77 210.08 200.63 191.21
#  229.19 220.56 244.18 245.7  238.18 213.81 224.   238.02 220.28 238.6
#  273.84 250.21 235.04 241.71 225.94 239.07 220.99 227.01 241.54 237.27
#  222.81 221.79 193.51 192.75 227.93 210.27 230.19 234.56 207.39 177.52
#  180.56 165.34 215.35 211.35 214.54 236.5  204.94 186.34 175.02 203.59
#  203.44 217.25 246.18 231.19 222.41 224.86 226.06 212.8  252.35 266.55
#  242.38 258.39 237.03 233.42 212.87 220.26 233.26 229.95 227.13 209.19
#  208.88 198.08 174.06 186.1  186.21 199.55 217.01 218.65 201.6  160.18
#  161.14 186.29 175.4  218.64 211.71 189.22 203.38 184.57 176.72 173.31
#  181.61]

# %% [markdown]
# The goal of this exercise is to use several (let us say $N$) previous share prices in order to predict the share price for today. This is useful because we can buy or sell the price before its price rises or falls and in that way increase our profit or lower our loss. The first step is to find the input-output pairs, which will be used on order to train our network. The size of this set will be defined using variable $i$. Our inputs will be vectors $\mathbf{a}_i$, which we put in matrix $\mathbf{A}$. Outputs are scalar values, which we put in vector $y$.
#
# **Tasks**
#
# 1. Write the function *memory*, which for given day in the year (index of the variable *data*) constructs a column vector $\mathbf{a}$ whose elements represent the prices for last *N* days but without the price for today.
# 2. Using the function *memory* write a function *memorize*, which for given inputs (*data*, *day*, *N*, *i*) constructs the matrix $\mathbf{A}$ in which each column vector represents the $\mathbf{a}_i$ for the previous day. So, matrix $\mathbf{A}$ memorizes $i$ memories which we will use in order to train our network.

# %%
# WRITE YOUR CODE HERE
def memory(data, day, N):
  return np.array([data[day-N: day]]).T

def memorize(data, day, N, i):
  A = memory(data, day-i, N)
  for j in range(day-i+1, day):
    A = np.hstack([A, memory(data, j, N)])
  return A
# memory(data, 5, 3)
print(memorize(data, 10, 3, 5))
print()
print(data)
# Out:
# [[214.58 214.36 229.04 199.32 203.02]
#  [214.36 229.04 199.32 203.02 213.71]
#  [229.04 199.32 203.02 213.71 201.54]]
#
# [183.35 210.26 214.58 214.36 229.04 199.32 203.02 213.71 201.54 245.35
#  219.03 238.02 222.02 205.7  174.35 190.18 203.97 215.83 231.49 214.84
#  202.23 173.53 181.16 148.12 178.15 179.09 190.47 190.73 155.93 156.66
#  138.9  166.83 151.45 165.21 206.64 170.25 158.17 146.52 140.63 163.85
#  189.44 212.95 219.97 213.68 192.39 189.87 195.83 185.06 192.2  226.31
#  210.14 203.82 198.05 188.79 181.04 165.08 176.82 194.66 215.64 193.73
#  193.16 180.14 149.81 138.93 171.2  190.08 176.88 176.37 150.28 164.23
#  139.97 148.53 150.8  161.31 167.55 194.3  180.83 146.55 171.8  172.52
#  188.95 219.83 190.75 203.71 195.17 187.47 163.97 194.88 186.25 221.66
#  234.34 219.65 210.34 179.24 189.42 183.05 184.15 206.99 205.8  196.47
#  194.92 174.1  161.27 156.88 194.45 206.79 188.01 194.26 185.98 178.62
#  171.61 156.83 163.33 204.55 185.24 183.74 180.39 189.12 176.08 185.65
#  217.03 220.8  207.63 237.17 218.2  201.81 190.05 197.65 222.42 227.66
#  227.12 226.35 215.54 198.27 207.58 220.6  232.32 243.92 243.58 241.19
#  221.24 181.33 204.45 171.85 206.02 200.78 206.16 202.9  182.28 180.14
#  192.17 176.4  199.22 215.79 227.95 211.93 218.77 210.08 200.63 191.21
#  229.19 220.56 244.18 245.7  238.18 213.81 224.   238.02 220.28 238.6
#  273.84 250.21 235.04 241.71 225.94 239.07 220.99 227.01 241.54 237.27
#  222.81 221.79 193.51 192.75 227.93 210.27 230.19 234.56 207.39 177.52
#  180.56 165.34 215.35 211.35 214.54 236.5  204.94 186.34 175.02 203.59
#  203.44 217.25 246.18 231.19 222.41 224.86 226.06 212.8  252.35 266.55
#  242.38 258.39 237.03 233.42 212.87 220.26 233.26 229.95 227.13 209.19
#  208.88 198.08 174.06 186.1  186.21 199.55 217.01 218.65 201.6  160.18
#  161.14 186.29 175.4  218.64 211.71 189.22 203.38 184.57 176.72 173.31
#  181.61]

# %%
memory(data, 150, 100)
# Out:
# array([[210.14],
#        [203.82],
#        [198.05],
#        [188.79],
#        [181.04],
#        [165.08],
#        [176.82],
#        [194.66],
#        [215.64],
#        [193.73],
#        [193.16],
#        [180.14],
#        [149.81],
#        [138.93],
#        [171.2 ],
#        [190.08],
#        [176.88],
#        [176.37],
#        [150.28],
#        [164.23],
#        [139.97],
#        [148.53],
#        [150.8 ],
#        [161.31],
#        [167.55],
#        [194.3 ],
#        [180.83],
#        [146.55],
#        [171.8 ],
#        [172.52],
#        [188.95],
#        [219.83],
#        [190.75],
#        [203.71],
#        [195.17],
#        [187.47],
#        [163.97],
#        [194.88],
#        [186.25],
#        [221.66],
#        [234.34],
#        [219.65],
#        [210.34],
#        [179.24],
#        [189.42],
#        [183.05],
#        [184.15],
#        [206.99],
#        [205.8 ],
#        [196.47],
#        [194.92],
#        [174.1 ],
#        [161.27],
#        [156.88],
#        [194.45],
#        [206.79],
#        [188.01],
#        [194.26],
#        [185.98],
#        [178.62],
#        [171.61],
#        [156.83],
#        [163.33],
#        [204.55],
#        [185.24],
#        [183.74],
#        [180.39],
#        [189.12],
#        [176.08],
#        [185.65],
#        [217.03],
#        [220.8 ],
#        [207.63],
#        [237.17],
#        [218.2 ],
#        [201.81],
#        [190.05],
#        [197.65],
#        [222.42],
#        [227.66],
#        [227.12],
#        [226.35],
#        [215.54],
#        [198.27],
#        [207.58],
#        [220.6 ],
#        [232.32],
#        [243.92],
#        [243.58],
#        [241.19],
#        [221.24],
#        [181.33],
#        [204.45],
#        [171.85],
#        [206.02],
#        [200.78],
#        [206.16],
#        [202.9 ],
#        [182.28],
#        [180.14]])

# %% [markdown]
# Construct the matrix $\mathbf{A}$ using the command:

# %%
day=151
N=70  # rows
i=50  # columns
A=memorize(data, day, N, i)
print(A)
print(A.shape)
# Out:
# [[166.83 151.45 165.21 ... 171.8  172.52 188.95]
#  [151.45 165.21 206.64 ... 172.52 188.95 219.83]
#  [165.21 206.64 170.25 ... 188.95 219.83 190.75]
#  ...
#  [205.8  196.47 194.92 ... 200.78 206.16 202.9 ]
#  [196.47 194.92 174.1  ... 206.16 202.9  182.28]
#  [194.92 174.1  161.27 ... 202.9  182.28 180.14]]
# (70, 50)

# %% [markdown]
# The output vector is constructed using the command:

# %%
y=np.array([data[day-i+1:day+1]])
print(y)
print(y.size)
# Out:
# [[161.27 156.88 194.45 206.79 188.01 194.26 185.98 178.62 171.61 156.83
#   163.33 204.55 185.24 183.74 180.39 189.12 176.08 185.65 217.03 220.8
#   207.63 237.17 218.2  201.81 190.05 197.65 222.42 227.66 227.12 226.35
#   215.54 198.27 207.58 220.6  232.32 243.92 243.58 241.19 221.24 181.33
#   204.45 171.85 206.02 200.78 206.16 202.9  182.28 180.14 192.17 176.4 ]]
# 50

# %% [markdown]
# We initialize the perceptron as follows:

# %%
def initp(data, labels):
    return -0.5+np.random.rand(labels.shape[0], data.shape[0]+1)

W=initp(A, y)
print(W.shape)
print(W)
# Out:
# (1, 71)
# [[-0.06171399  0.35125605 -0.13512508 -0.24866472  0.18463623 -0.271785
#   -0.28663398  0.46642942 -0.14475528  0.44829069  0.29439056 -0.40570739
#   -0.30494436 -0.09222045  0.05898139  0.10019228  0.45747694 -0.46328016
#   -0.10695345  0.44073231  0.17367056  0.4899253   0.36996897 -0.21732194
#    0.02820784  0.426137   -0.16768497 -0.12885521 -0.45112943 -0.42737267
#    0.33818432 -0.47475471  0.13590505  0.18068091  0.1460136  -0.49063275
#   -0.38732883 -0.21246067  0.01818115 -0.05152317 -0.09544313 -0.22341105
#    0.47029731  0.02559209 -0.05516671 -0.06046263 -0.312697   -0.42239957
#    0.20480771  0.41084516 -0.08668008  0.31690249  0.15202972 -0.22940193
#    0.4126638   0.32097929  0.01981942  0.2623448  -0.12609177 -0.13779688
#    0.48242694  0.06998307 -0.39348922  0.06840668 -0.21487463  0.44594045
#   -0.36379099  0.32164475 -0.08652486  0.00915577  0.49982395]]

# %% [markdown]
# We train the perceptron using the command:

# %%
ni=1e-8
max_num_iter=10000

W1, errors=trainlms(ni, A, y, W, max_num_iter)
print('W1: ', W1)
print('errors: ', errors)
print('last error: ', errors[-1])
# Out:
# W1:  [[-0.06193893  0.20695211  0.01119501 -0.03199328 -0.03881222 -0.10306463
#   -0.13551633  0.2876752  -0.12525184  0.27150786 -0.16872782 -0.3185748
#   -0.24537866 -0.08297354  0.05709266 -0.04632961  0.16457275 -0.13306799
#   -0.2117784   0.12871045  0.12077431  0.18889251  0.23961008 -0.22365603
#    0.17682659  0.06655945 -0.04979509  0.12387847 -0.17600283 -0.17918228
#    0.20989725 -0.2981615   0.3101457   0.25714794  0.27670141 -0.1742661
#   -0.34906085  0.12283632  0.14199285 -0.10875846  0.06431517 -0.29464172
#    0.36716847  0.41199318  0.07676616 -0.00472175 -0.15371529 -0.23218168
#   -0.02791105  0.17597115 -0.19012284  0.12198468 -0.05797113 -0.19968932
#    0.26915618  0.15904177  0.08489574  0.19259593 -0.10584263 -0.10936297
#    0.34880899  0.09099404 -0.27186149 -0.11717019 -0.24148137  0.20801607
#   -0.26757508  0.19671162 -0.10791815  0.1144701   0.38681769]]
# errors:  [421438.51352345914, 195540.39999796802, 180957.57754711708, 179393.8778075022, 178635.58206238644, 177930.38910661242, 177231.94345681762, 176537.37120208645, 175846.47670277528, 175159.2293832248, 174475.60893468477, 173795.59578032175, 173119.17048738894, 172446.31373048437, 171777.0062887548, 171111.22904519332, 170448.96298606877, 169790.18920036647, 169134.88887923208, 168483.04331541876, 167834.6339027372, 167189.6421355085, 166548.0496080206, 165909.8380139869, 165274.98914600824, 164643.4848950377, 164015.30724984806, 163390.4382965033, 162768.86021783133, 162150.55529289966, 161535.50589649635, 160923.69449861065, 160315.103663918, 159709.71605126798, 159107.51441317427, 158508.48159530837, 157912.60053599477, 157319.85426571008, 156730.22590658418, 156143.69867190422, 155560.2558656216, 154979.8808818608, 154402.55720443223, 153828.26840634627, 153256.99814933096, 152688.73018335187, 152123.44834613448, 151561.13656268967, 151001.77884484138, 150445.35929075637, 149891.8620844778, 149341.27149546, 148793.57187810674, 148248.74767131126, 147706.7833979997, 147167.66366467558, 146631.37316096856, 146097.89665918399, 145567.21901385597, 145039.32516130255, 144514.2001191828, 143991.82898605728, 143472.19694095023, 142955.28924291403, 142441.0912305964, 141929.58832180998, 141420.76601310374, 140914.60987933722, 140411.10557325694, 139910.23882507492, 139411.99544204978, 138916.36130806987, 138423.32238323864, 137932.86470346258, 137444.97438004107, 136959.63759925833, 136476.84062197848, 135996.56978324123, 135518.81149186136, 135043.55223002937, 134570.7785529146, 134100.47708827045, 133632.63453604197, 133167.23766797525, 132704.2733272289, 132243.72842798833, 131785.58995508077, 131329.84496359417, 130876.48057849625, 130425.48399425719, 129976.84247447345, 129530.54335149401, 129086.57402604859, 128644.92196687753, 128205.57471036432, 127768.51986016969, 127333.74508686748, 126901.23812758308, 126470.98678563364, 126042.9789301695, 125617.20249581904, 125193.64548233368, 124772.29595423641, 124353.14204047114, 123936.17193405445, 123521.37389172912, 123108.7362336193, 122698.24734288847, 122289.89566539749, 121883.66970936641, 121479.55804503713, 121077.54930433765, 120677.63218054872, 120279.79542797251, 119884.02786160182, 119490.31835679278, 119098.65584893772, 118709.02933314117, 118321.42786389662, 117935.84055476531, 117552.25657805764, 117170.66516451428, 116791.05560299144, 116413.41724014582, 116037.73948012266, 115664.0117842445, 115292.22367070247, 114922.36471424835, 114554.42454588933, 114188.39285258333, 113824.2593769369, 113462.01391690418, 113101.64632548788, 112743.14651044122, 112386.50443397276, 112031.71011245095, 111678.7536161125, 111327.62506877004, 110978.31464752342, 110630.81258247104, 110285.10915642374, 109941.19470461961, 109599.05961444076, 109258.69432513128, 108920.08932751691, 108583.23516372648, 108248.1224269143, 107914.74176098447, 107583.08386031643, 107253.13946949254, 106924.89938302607, 106598.3544450919, 106273.49554925777, 105950.3136382174, 105628.79970352502, 105308.94478533124, 104990.73997212018, 104674.1764004488, 104359.24525468629, 104045.93776675657, 103734.24521588025, 103424.15892831991, 103115.67027712535, 102808.77068188088, 102503.45160845392, 102199.70456874456, 101897.5211204372, 101596.89286675268, 101297.81145620267, 101000.26858234446, 100704.25598353772, 100409.76544270254, 100116.78878707821, 99825.31788798432, 99535.3446605819, 99246.86106363694, 98959.85909928475, 98674.33081279536, 98390.2682923404, 98107.66366876177, 97826.5091153406, 97546.79684756795, 97268.51912291694, 96991.6682406157, 96716.23654142207, 96442.21640739877, 96169.6002616905, 95898.38056830192, 95628.54983187678, 95360.10059747854, 95093.0254503717, 94827.31701580487, 94562.96795879447, 94299.97098391027, 94038.31883506116, 93778.00429528294, 93519.02018652704, 93261.35936944984, 93005.01474320404, 92749.97924523032, 92496.24585105071, 92243.80757406267, 91992.65746533469 ...
# last error:  6672.189392364762

# %% [markdown]
# Weights of the network are memorized in the matrix $\mathbf{W}_1$. Variable *ni* should be experimentally found. Train the network for different values of *i*, *N*, *max_num_iter*. We can visualize the output of the network on the training data using the following command:

# %%
p=predict(W1, A)

print(y[0])

plt.plot(range(1, y[0].shape[0]+1), y[0])
plt.plot(range(1, p[0].shape[0]+1), p[0], c="red")
plt.show()
# Out:
# [161.27 156.88 194.45 206.79 188.01 194.26 185.98 178.62 171.61 156.83
#  163.33 204.55 185.24 183.74 180.39 189.12 176.08 185.65 217.03 220.8
#  207.63 237.17 218.2  201.81 190.05 197.65 222.42 227.66 227.12 226.35
#  215.54 198.27 207.58 220.6  232.32 243.92 243.58 241.19 221.24 181.33
#  204.45 171.85 206.02 200.78 206.16 202.9  182.28 180.14 192.17 176.4 ]

# %% [markdown]
# Here, the blue color shows the predicted values and the red color shows the real outputs.
#
# **Tasks**
#
# 1. Memorize different weight matrices ($\mathbf{W}_1$, $\mathbf{W}_2$...) with different combinations of following parameters *i*=30, 50 or 100; *N*=20, 50 or 80; *max_num_iter*=10000, 50000 or 500000. (Choose 6 different combinations.) For selected parameter combinations show the obtained predictions with real values. Comment the obtained results.

# %%
# WRITE YOUR CODE HERE
# Error on 100 80 10000 -> N < days - i
import itertools

i_set, N_set, iter_set = [30, 50, 100], [20, 50, 80], [10000, 50000, 500000]

w_err = []
for i, N, max_num_iter in itertools.product(i_set, N_set, iter_set):
  if i == 100 and N == 80:
    break
  print(i, N, max_num_iter)
  A = memorize(data, day, N, i)
  y = np.array([data[day-i+1:day+1]])
  W = initp(A, y)
  W1, errors = trainlms(ni, A, y, W, max_num_iter)
  print(W1, errors[-1])
  w_err.append((W1, errors[-1]))
# Out:
# 30 20 10000
# [[-0.2469289   0.15648488 -0.36794094  0.14259924 -0.34651023  0.32819402
#   -0.10952392  0.56633183 -0.13528792 -0.21002076 -0.26860811 -0.05438088
#   -0.08223186  0.24797323  0.30911276 -0.2234879   0.36103648 -0.18941642
#    0.41553321  0.22948346  0.21592611]] 7170.487011878783
# 30 20 50000
# [[ 0.42163692 -0.02790138 -0.29889384  0.10211489 -0.41841779 -0.05565707
#    0.15754631  0.53897828  0.32360285 -0.23841172 -0.17634719 -0.01997934
#    0.07363726 -0.16664457  0.24488104 -0.08316843  0.05400399  0.07793432
#   -0.08732233  0.27174977  0.71036781]] 2283.9875042675876
# 30 20 500000
# [[ 0.0897906  -0.06075459 -0.00288225  0.36705212 -0.71192816 -0.29127235
#    0.00404821  0.6511548   0.44499064 -0.34825865 -0.1418425   0.05580482
#    0.11941814 -0.34648913  0.24316185  0.0482158   0.21181049 -0.11327526
#   -0.59965127  0.27165875  1.18722492]] 1515.5034420030686
# 30 50 10000
# [[-0.1195926  -0.01940732 -0.05425349 -0.17669896  0.62573163  0.55107652
#    0.28492622  0.22451744 -0.14717986  0.01624783  0.2776613   0.33671566
#   -0.13753837 -0.06370482  0.0660487   0.34578776 -0.1077019   0.41050931
#    0.22906982 -0.11204194  0.45232511 -0.27659326 -0.36994071 -0.0566782
#   -0.49148276  0.07283293  0.06858974  0.01688814  0.14885221 -0.0649128
#   -0.4369415   0.13857158  0.28232552 -0.13162911  0.26621654 -0.36307954
#   -0.09936916  0.38788397  0.22807088 -0.09955097  0.02402123  0.03809639
#   -0.16590274  0.12987381 -0.42640089  0.15777701 -0.12356284 -0.33093639
#    0.09906771 -0.29353402 -0.14954372]] 4264.2427206790435
# 30 50 50000
# [[ 0.38334738 -0.12465063  0.11458621 -0.2224078   0.26488115  0.10094886
#   -0.1218371   0.20688447  0.39061315  0.17366245 -0.29303319 -0.00099023
#    0.54579336  0.12896977  0.24087096  0.12521283 -0.01175154 -0.22672639
#   -0.15305432  0.24485541  0.13881558 -0.12949131 -0.1365351   0.04466264
#   -0.38378307  0.32023456  0.06663163 -0.04486144 -0.37402641  0.04399267
#   -0.00602133 -0.12381176 -0.2020056   0.21442237  0.1030348   0.00541117
#    0.39292397  0.28605249 -0.05876605 -0.005954   -0.19757679 -0.01789022
#   -0.06484987  0.04860407 -0.10105041 -0.1767488  -0.2051672   0.18397775
#    0.01437474 -0.12719496  0.21101141]] 182.4930799679184
# 30 50 500000
# [[ 0.4121503  -0.03970942 -0.1444355   0.03378802  0.33891093  0.17014699
#   -0.17252663  0.15232796 -0.02493627  0.01732556 -0.17485635  0.06011348
#    0.14489343 -0.28844858 -0.09638679 -0.20656562 -0.14280397 -0.17015111
#    0.0342365   0.19526199  0.00145197  0.48301904  0.01397654  0.63110614
#   -0.27547418  0.36025602 -0.05487584 -0.03436687  0.0674083  -0.22328675
#   -0.01954319 -0.31301984 -0.22598548 -0.06267091 -0.22117497  0.04992323
#    0.16583376 -0.00285666 -0.12210559 -0.02541932 -0.00512071  0.09059985
#    0.03859951 -0.24773411  0.1564366   0.21349006  0.06443692  0.29465948
#    0.21737051  0.0317587   0.28634729]] 0.019999852508949117
# 30 80 10000
# [[-0.07867636  0.22448726  0.09580165  0.22810358  0.07211572 -0.35258057
#   -0.13972475 -0.13649573  0.0687183  -0.16679467 -0.4380505   0.31641605
#    0.26177143 -0.280434   -0.09807198  0.26494392 -0.34714001 -0.24958499
#   -0.20436086  0.179668   -0.0152713  -0.04207402 -0.10291306 -0.34472525
#   -0.32952525  0.26630645  0.20652433  0.32229681 -0.06084115 -0.38988994
#   -0.25068703 -0.1212718   0.01469006 -0.40349812  0.03052581 -0.08096731
#   -0.03280383  0.07227328  0.17725579  0.12535732 -0.11695277  0.01228355
#    0.34318029  0.30776126  0.37630104 -0.17563319  0.08503143 -0.19513465
#    0.42725334  0.37921351 -0.31158214 -0.45605403 -0.12178547  0.22160849
#   -0.1228059   0.37066188  0.31650032  0.14002071  0.11655481 -0.30930543
#   -0.18404191  0.0283541   0.04223666  0.41140174 -0.27250697  0.05269868
#    0.34584834  0.27517458 -0.05780909  0.46652655  0.23445605 -0.23821105
#   -0.01771702 -0.43946107 -0.02327573 -0.20184209  0.35333656  0.06041646
#   -0.21447921  0.21236676  0.44983204]] 2285.97831645854
# 30 80 50000
# [[-0.16180494  0.27481356  0.02331646 -0.22787091  0.00273877  0.30990539
#   -0.35151716  0.31072917 -0.06653859 -0.00232328  0.12281784  0.30576975
#    0.13662631  0.22372974 -0.07920597 -0.15960801  0.13273594 -0.25239693
#   -0.47452807  0.09997822  0.17270502  0.03361477  0.07507579  0.27610549
#    0.16398864  0.1015358   0.28249751  0.08702052 -0.19028762  0.21618417
#   -0.01582645 -0.42622254 -0.14239871  0.02601495  0.12343917  0.05048802
#   -0.05754557  0.48731605  0.55966805  0.25500597  0.10062248 -0.27067818
#   -0.08463862 -0.05325738  0.10212716 -0.47526642 -0.02184983  0.17759877
#   -0.13147391  0.17175405  0.20903873  0.21854907 -0.18643467 -0.30146726
#   -0.24857817 -0.2535294  -0.25779421  0.17577673 -0.08127112  0.0829487
#    0.16267373  0.23066702 -0.08323462 -0.09123218 -0.30134212  0.00865655
#    0.18006662 -0.08731646 -0.1243018  -0.32518972 -0.17074552  0.33991346
#   -0.12841099  0.15461941  0.3039517  -0.07222739 -0.2529157   0.0795851
#   -0.23286609  0.13630278  0.15901369]] 136.0316951566343
# 30 80 500000
# [[ 4.44024072e-01  2.13481984e-02  8.52775231e-02  1.32307071e-01
#    1.02454712e-01  1.10561242e-01 -3.56536729e-01 -1.62317459e-01
#    1.48441929e-01 -2.83280505e-01  8.63682126e-03  3.20448579e-01
#   -2.00835442e-01 -2.33903438e-01 -4.85622034e-01  1.35717579e-01
#   -2.28153518e-01 -3.02952849e-01 -1.39684935e-01  2.73292139e-01
#   -4.63804771e-01 -5.76891844e-02 -8.98952969e-02  2.44093810e-01
#   -2.63716680e-01 -4.20401642e-02 -2.05581512e-01  3.15748357e-01
#    3.27706345e-01 -4.82611283e-02 -2.59523067e-01 -1.99535261e-01
#    3.50747033e-01 -2.83143659e-01  2.03135558e-01  3.11461751e-01
#    8.38667375e-02 -2.82131182e-01  1.88248603e-01  8.66419848e-02
#    4.93737092e-01 -3.00997793e-01  2.88617563e-02  7.23135691e-02
#   -1.07052597e-01  5.47681115e-02  3.04484844e-01  1.65163008e-01
#   -1.81296345e-01  6.45080451e-02  3.23614269e-01 -8.00998211e-02
#    3.01522026e-01  3.15400345e-01  2.25443910e-01 -1.53454618e-01
#    3.18541490e-01  5.59765248e-02  2.84244526e-01  5.56311371e-02
#    2.08332692e-01  4.57391362e-02 -1.37458512e-01  4.52301495e-02
#   -2.47092391e-01  5.66006655e-01 -1.37451457e-02 -2.75128236e-02
#   -1.02950189e-02 -1.01394326e-01  1.79140506e-01 -1.75786732e-01
#   -2.01315969e-04 -3.25638490e-01  1.20989327e-02 -2.63075874e-01
#   -2.98629247e-01  1.61160926e-02  2.28746165e-01  2.88091824e-01
#   -6.72785172e-02]] 0.019999115086898413
# 50 20 10000
# [[-0.0548858   0.10719482 -0.07153125 -0.25939976 -0.12797908 -0.05629532
#    0.18135638  0.47868187  0.11663213 -0.34934326  0.00989551 -0.15652991
#    0.0889464  -0.07096278  0.31973076 -0.12890541  0.0162595   0.00820831
#    0.16367969  0.28732282  0.44086839]] 9652.405129685465
# 50 20 50000
# [[-0.13204434 -0.01534014 -0.08942816  0.10272941 -0.31833314 -0.18992567
#    0.26676904  0.47266167  0.08928437  0.13387504 -0.42548954 -0.1519865
#    0.06123346 -0.08807217  0.31135584  0.0260616  -0.18094348 -0.07671928
#    0.20745001  0.27458022  0.58801337]] 7275.41459908935
# 50 20 500000
# [[ 0.41936342  0.20122577 -0.04154264  0.06070764 -0.56149203 -0.3136099
#    0.30420258  0.5313833   0.25138734 -0.00661627 -0.3797815  -0.32353824
#    0.21266401  0.02016228  0.40174974 -0.07434417 -0.40274838 -0.19131593
#    0.2236616   0.51850599  0.57132143]] 6553.598953089916
# 50 50 10000
# [[ 3.02895124e-01 -8.81862773e-02 -1.96387961e-01 -2.29973288e-01
#    5.42601937e-01  1.97219874e-01 -3.06907787e-02  2.78214695e-01
#   -2.07771175e-01  4.15368917e-01  1.00381009e-01 -2.69597108e-01
#    4.83977514e-01 -7.10620166e-02 -1.49571497e-01 -3.15526762e-02
#    1.04702184e-01 -3.60108010e-02 -1.87435369e-01 -9.26508782e-02
#    1.78317783e-01 -4.58662536e-04  3.68977862e-01  2.50269802e-02
#   -6.80798468e-02 -2.49161878e-01  2.05503958e-01 -7.00738529e-02
#   -8.57673017e-02  2.47913982e-01  1.41094145e-02  8.63211228e-02
#   -2.79649429e-02 -1.89336945e-01  1.70158625e-01 -2.33394329e-01
#   -9.17382075e-02  2.81122383e-01 -2.75045121e-01 -2.01490370e-01
#    3.43946648e-02  1.25231148e-01 -6.86637513e-02  3.73635147e-01
#   -2.36271597e-02 -3.17309696e-01 -2.02532429e-01 -1.00532154e-02
#    2.64763748e-01 -3.62421532e-02  3.28159798e-01]] 6714.084281411826
# 50 50 50000
# [[ 1.77330412e-04 -1.72483928e-02  1.69063481e-01  8.51886752e-02
#    1.51952485e-01 -8.06285097e-02 -1.40155675e-01  1.75612413e-01
#   -5.24600931e-02 -1.97906498e-01  1.10296290e-01 -3.84685316e-02
#    2.31360331e-01  1.22300799e-01  1.33775024e-01  1.45945620e-01
#    4.09989573e-02  2.15183964e-01  7.72783528e-02 -5.35426015e-02
#    2.04304519e-01  1.10802594e-01  1.71870865e-01  2.50060311e-01
#   -1.27856764e-01 -1.17706739e-01 -1.00651492e-01 -1.95742067e-01
#   -4.03215918e-02 -1.78756698e-01 -3.85981099e-01 -1.58437733e-01
#   -1.74304574e-01  7.62850443e-02  1.99857367e-01  1.40527969e-01
#    7.53941864e-02  3.05323025e-01  1.21220069e-01  1.42107673e-01
#    6.28523371e-03 -2.35723278e-01  1.64384753e-02 -9.48270500e-02
#    2.05236018e-01  8.31287661e-02 -1.44696657e-01 -2.13002075e-01
#    1.76222405e-01  4.61375298e-02 -1.37182045e-01]] 1484.1580575292514
# 50 50 500000
# [[ 0.24619703 -0.0771954   0.30172574 -0.16555356  0.23290368  0.02322838
#   -0.1216928   0.21517272  0.00514063 -0.34259747 -0.19803751 -0.09721306
#    0.56066708 -0.0022941   0.1854514   0.06172754 -0.31683034  0.03825124
#    0.08111062  0.21278098  0.12778744 -0.10703885  0.09038252  0.24076186
#    0.04502316  0.20916803  0.07312888 -0.1439651  -0.20513269  0.00940695
#   -0.27422524 -0.25887667 -0.24136012  0.00775088  0.01536092  0.00357891
#    0.20196803  0.27353965 -0.21121388  0.39119259 -0.09749521 -0.15541991
#    0.01143947 -0.08175304 -0.01618077  0.1346187  -0.09089773 -0.00740836
#    0.32935862  0.11796133  0.07279234]] 757.4739261393562
# 50 80 10000
# [[ 0.04076092  0.09609728 -0.01815842  0.14360575  0.2553832   0.00107272
#   -0.12993998 -0.08553383  0.22274879  0.49965634 -0.02209839 -0.11571571
#    0.1238216   0.21512215 -0.43297982 -0.01211638  0.10373555 -0.14753813
#   -0.08645078  0.1105321  -0.04254832 -0.23889762  0.2453359   0.0735583
#   -0.07106187  0.09197888 -0.0534798   0.2060929  -0.22724396 -0.40054027
#   -0.090181   -0.04982781 -0.16176228  0.04018472 -0.02557097 -0.08247256
#   -0.01951863  0.2547848   0.01034639  0.12948011  0.33509707  0.18011598
#   -0.17621113 -0.16753367  0.02593372 -0.12487019 -0.07591847 -0.31497346
#   -0.30434466  0.18620697  0.01784054 -0.01139262  0.2328452   0.16645272
#   -0.14537632  0.19482125 -0.10883246 -0.31023455 -0.06794436  0.1486662
#   -0.38306458  0.22280029  0.2328247   0.35868745 -0.23041663  0.04639131
#   -0.01448843  0.39843322 -0.26955086 -0.10537285  0.10639826 -0.21852766
#    0.07903798  0.24753763  0.20529116 -0.06394025  0.45920889  0.15328152
#   -0.0596994  -0.03313249 -0.08823322]] 6308.611191803293
# 50 80 50000
# [[-0.347835   -0.19212718 -0.07337443  0.08919744 -0.21846208  0.29818785
#    0.3125932   0.07464815  0.09988257 -0.00899331 -0.40465148  0.20121532
#   -0.16978626 -0.04262794  0.11073856  0.10078142  0.24767382  0.10822081
#    0.24908691  0.04679764 -0.35501088  0.05460491 -0.10639993 -0.11282505
#   -0.02093828  0.00844795  0.08697766  0.06366946 -0.09343338  0.11363665
#   -0.09027159 -0.23977303 -0.04034966  0.07569422  0.2776248   0.31709482
#    0.05966833 -0.07719635 -0.08873734 -0.11852753 -0.3439789  -0.10066878
#    0.65008733  0.14895897 -0.18058451 -0.06179377  0.12266492 -0.04152572
#    0.44859363  0.33208086  0.00707356 -0.09005519  0.02846608  0.09031466
#   -0.15527075 -0.44330545 -0.22851136 -0.26807228 -0.30844454  0.15284525
#    0.25809671 -0.08720892 -0.24951438  0.17265345 -0.3068372  -0.10613749
#    0.19292414  0.07320936  0.24601579  0.31793315  0.29405319  0.16409799
#    0.09208803 -0.08850091  0.11325528 -0.22299163 -0.26253858 -0.28139156
#    0.00142919  0.30823426  0.1556927 ]] 403.141409831496
# 50 80 500000
# [[ 2.11816256e-01 -3.30057635e-01 -2.80725022e-01  6.33834256e-01
#   -3.47591948e-01  1.56041058e-01  3.69547811e-01 -4.88464265e-02
#    8.26763335e-02  3.59654654e-02 -2.53220328e-01  4.60683303e-01
#   -3.87927521e-02 -2.88891684e-02 -3.45904346e-01  6.88144889e-02
#   -3.35236536e-01 -1.41378319e-01 -3.62277839e-01  3.92856123e-01
#   -1.84345206e-01  2.56440656e-01  1.64975132e-01 -9.30090347e-03
#   -7.16372873e-02 -1.36020722e-01 -1.88883024e-01  1.64319115e-01
#    1.50448730e-02  1.70991037e-01 -8.72379863e-02 -4.45912165e-02
#    1.51859201e-01 -4.13706072e-01  3.49353111e-01  2.32795139e-01
#    2.08539289e-01  1.51255215e-01 -1.72493828e-02  2.80823541e-02
#    1.65791268e-01 -1.68496544e-01  2.67940388e-01 -1.06709413e-01
#   -1.49967827e-01 -1.18581739e-01 -3.44171701e-01 -4.77609981e-02
#    2.19093926e-01  6.83651193e-02  2.30239375e-01  2.92897472e-02
#    1.50051406e-01  2.44000908e-01 -4.70493529e-02 -4.06988497e-04
#    2.95977508e-01  1.18086620e-01  1.16619751e-01 -3.45476396e-01
#    1.55900493e-01 -3.35658232e-01 -2.05759000e-01  1.97160620e-01
#    6.68563357e-02  2.91330683e-01  1.98313710e-01 -1.76917440e-01
#   -3.41264073e-01 -1.28869559e-01 -2.58971923e-01 -2.13263316e-01
#    6.54768391e-01  1.31571718e-02 -1.33900849e-01  2.95433999e-01
#   -4.12413413e-01  1.44887342e-01  3.29782511e-01 -3.52289580e-02
#   -3.27203833e-02]] 0.019999709449740062
# 100 20 10000
# [[ 0.2946011   0.14405644 -0.17111999 -0.00247868 -0.04397733 -0.02987055
#    0.17632655  0.21389192 -0.00153133 -0.10099334 -0.27201269 -0.03096108
#   -0.19222993  0.05260793  0.28086099  0.22137912 -0.07058879 -0.02123344
#    0.18922328  0.26641583  0.39338602]] 22704.348920502343
# 100 20 50000
# [[ 0.04188724  0.02848283 -0.02772681  0.02251738 -0.14333622 -0.14602438
#    0.28196371  0.29986252  0.08364096 -0.22449104 -0.24863713 -0.08148673
#   -0.09817497  0.07861571  0.1962828   0.08736596  0.02817092  0.00050158
#    0.089983    0.2839825   0.48832358]] 20864.14929594555
# 100 20 500000
# [[-0.18055694  0.02680114 -0.02747811  0.02775257 -0.14558542 -0.14892485
#    0.28122376  0.29746009  0.08989824 -0.23032399 -0.24190107 -0.08567748
#   -0.09737707  0.07863892  0.19617696  0.08778259  0.03147357 -0.00317854
#    0.08794271  0.28017244  0.49376976]] 20848.355013607426
# 100 50 10000
# [[-0.15639149 -0.040473   -0.3639464  -0.09835793  0.17255472  0.15668828
#   -0.00919769 -0.03364726 -0.05365317 -0.0614186  -0.01783516 -0.15531964
#    0.24009879  0.13514603  0.11427886  0.05431071 -0.18812541  0.06837944
#   -0.00661673  0.04547908  0.22454744 -0.05871354  0.08299541  0.26721251
#   -0.27960148  0.05997061  0.00131531  0.14090474 -0.06961716 -0.01790089
#   -0.27238806 -0.27605607  0.0061466   0.17443438  0.02361754 -0.07545724
#    0.31477372  0.15155974 -0.16592702 -0.04587892  0.11262452  0.13663996
#    0.14296493 -0.11601973 -0.02297471 -0.05230033  0.05153973  0.21784115
#   -0.02660732  0.17631638  0.24780109]] 11841.34297335268
# 100 50 50000
# [[-0.08588127 -0.22905145 -0.17803717 -0.0168676   0.15325627  0.16890547
#   -0.11916437  0.04222989  0.04204246 -0.12739461 -0.07378406 -0.05745208
#    0.26523844  0.07156544  0.03821835 -0.02169489  0.04749485 -0.08828341
#   -0.02978092  0.07833125  0.09990153 -0.00930953  0.1640877   0.14044939
#   -0.16044997  0.0380816   0.11027975 -0.08487763 -0.01214566  0.04387092
#   -0.19766324 -0.16544027 -0.05065552  0.16370923 -0.05621212 -0.05895502
#    0.26098247  0.11648624 -0.03420509 -0.11544731  0.03197927  0.14340224
#    0.02777642  0.0303952   0.03754985 -0.14117432  0.05087285  0.06621058
#    0.1189625   0.1786887   0.30894774]] 8186.797330263966
# 100 50 500000
# [[ 0.45288897 -0.22752741 -0.17539967 -0.04674497  0.19910882  0.13902114
#   -0.1053963   0.03335762  0.0856318  -0.18431773 -0.06070067 -0.05090494
#    0.29376693  0.02228798  0.05516078  0.00074972  0.02780174 -0.09333274
#   -0.00928736  0.07432516  0.06147556  0.03404137  0.14950689  0.14625965
#   -0.192511    0.08983027  0.06964044 -0.07178637 -0.01821263  0.0796464
#   -0.23408914 -0.17062887 -0.01677378  0.15328607 -0.07059763 -0.04861216
#    0.26401356  0.10762232 -0.04483333 -0.08744725  0.01350798  0.12972583
#    0.03969149  0.05957083 -0.00714138 -0.11129893  0.03267005  0.07723256
#    0.08005337  0.23317928  0.29014376]] 8064.710336182178

# %% [markdown]
# If we do not use any intelligence for stock price prediction and we assume the price will be (almost) the same tomorrow, the error we make is:

# %%
a=data[day:day+1]          # price today - we assume the same price tomorrow
y=data[day+1:day+2]        # the real price tomorrow
print(a, y)
err_oo=np.sum(np.abs(y-a)) # error
err_oo
# Out:
# [176.4] [199.22]
# 22.819999999999993

# %% [markdown]
# If we use the network trained on previous days to predict the price for tomorrow, the error is as follows:

# %%
p=predict(W1, memorize(data, day+1, N, 1))
print(p)
err_nn=np.sum(np.abs(y-p))
err_nn
# Out:
# [[211.28620235]]
# 12.06620235232478

# %% [markdown]
# If we trade each day with the given stock, our error can be easily measured. Our potential profit can be calculated as follows:

# %%
profit=err_oo-err_nn
print(profit)
# Out:
# 10.753797647675214

# %% [markdown]
# To predict the price of the day after tomorrow, we could use the same network or we could train the network from scratch by also using the data of the day before the day after tomorrow i.e. by using the data of tomorrow. Which way would be better?
#
# **Tasks**
#
# 1. Create a table in which you will show the obtained profit levels depending on the parameters used (*i*, *N*, and *max_num_iter*). For of these parameter triplets the profit should be the sum of the profit for every possible *day* for which training data defined by *i* and *N* exists.
#   - Not interest in future predicted profit, but instead the profit from the training data?

# %%
# For one iteration
i, N, max_num_iter = 30, 20, 10000

A = memorize(data, day, N, i)
y = np.array([data[day-i+1:day+1]])
W = initp(A, y)
W1, errors = trainlms(ni, A, y, W, max_num_iter)
p = predict(W1, memorize(data, day+1, N, 1))
err_nn=np.sum(np.abs(data[day+1:day+2]-p))

profit=err_oo-err_nn
profit
# Out:
# 15.462151672204726

# %%
# WRITE YOUR CODE HERE
import itertools
from tabulate import tabulate


i_set, N_set, iter_set = [30, 50, 100], [20, 50, 80], [10000, 50000, 500000]

table_data = [['i', 'N', 'max_num_iter', 'profit']]

for i, N, max_num_iter in itertools.product(i_set, N_set, iter_set):
  if i == 100 and N == 80:
    break
  print(i, N, max_num_iter)
  A = memorize(data, day, N, i)
  y = np.array([data[day-i+1:day+1]])
  W = initp(A, y)
  W1, errors = trainlms(ni, A, y, W, max_num_iter)
  p = predict(W1, memorize(data, day+1, N, 1))
  err_nn=np.sum(np.abs(data[day+1:day+2]-p))  
  profit=err_oo-err_nn
  table_data.append([i, N, max_num_iter, profit])

print(tabulate(table_data, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# 30 20 10000
# 30 20 50000
# 30 20 500000
# 30 50 10000
# 30 50 50000
# 30 50 500000
# 30 80 10000
# 30 80 50000
# 30 80 500000
# 50 20 10000
# 50 20 50000
# 50 20 500000
# 50 50 10000
# 50 50 50000
# 50 50 500000
# 50 80 10000
# 50 80 50000
# 50 80 500000
# 100 20 10000
# 100 20 50000
# 100 20 500000
# 100 50 10000
# 100 50 50000
# 100 50 500000
# ╒═════╤═════╤════════════════╤════════════╕
# │   i │   N │   max_num_iter │     profit │
# ╞═════╪═════╪════════════════╪════════════╡
# │  30 │  20 │          10000 │  18.5627   │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  20 │          50000 │  17.9281   │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  20 │         500000 │  -0.156982 │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  50 │          10000 │ -21.8357   │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  50 │          50000 │   6.06622  │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  50 │         500000 │ -25.0374   │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  80 │          10000 │  11.0837   │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  80 │          50000 │  -7.12434  │
# ├─────┼─────┼────────────────┼────────────┤
# │  30 │  80 │         500000 │  -3.4147   │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  20 │          10000 │   7.67837  │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  20 │          50000 │   5.83001  │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  20 │         500000 │   5.45564  │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  50 │          10000 │  -2.53646  │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  50 │          50000 │  15.9501   │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  50 │         500000 │  16.1171   │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  80 │          10000 │   9.98571  │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  80 │          50000 │ -25.4108   │
# ├─────┼─────┼────────────────┼────────────┤
# │  50 │  80 │         500000 │   8.77857  │
# ├─────┼─────┼────────────────┼────────────┤
# │ 100 │  20 │          10000 │  10.4929   │
# ├─────┼─────┼────────────────┼────────────┤
# │ 100 │  20 │          50000 │  20.4944   │
# ├─────┼─────┼────────────────┼────────────┤
# │ 100 │  20 │         500000 │  20.4362   │
# ├─────┼─────┼────────────────┼────────────┤
# │ 100 │  50 │          10000 │  19.5598   │
# ├─────┼─────┼────────────────┼────────────┤
# │ 100 │  50 │          50000 │  17.6522   │
# ├─────┼─────┼────────────────┼────────────┤
# │ 100 │  50 │         500000 │  19.7578   │
# ╘═════╧═════╧════════════════╧════════════╛
